# %% [markdown]
# # Depth Map Prediction from a Single Image using a Multi-scale Deep Network

# %% [markdown]
# # Libraries required

# %%
import numpy as np
import pandas as pd
import cv2
import os
import time
import matplotlib.pyplot as plt
import hdf5storage
# %matplotlib inline

from keras.models import Sequential, model_from_json, Model, load_model
from keras.optimizers import SGD
from keras.layers import Input, Reshape, concatenate, Activation, Flatten, merge
from keras.layers import Convolution2D, MaxPooling2D, Dense, Dropout
from keras import backend as K
# Out:
# Using TensorFlow backend.
# /home/cse/ug/16075030/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# # File paths

# %%
coarse_dir='coarse_data/first_model.h5'
coarse_weights='coarse_weights.h5'
fine_dir='fine_data/first_model.h5'
fine_weights='fine_weights.h5'
path1='cafe/cafe_0001a/'
path2='cafe/cafe_0001b/'
path3='cafe/cafe_0001c/'

# %% [markdown]
# # Utillity functions

# %%
def scale_invarient_error(y_true,y_pred):
    log_1=K.log(K.clip(y_pred,K.epsilon(),np.inf)+1.)
    log_2=K.log(K.clip(y_true,K.epsilon(),np.inf)+1.)
    return K.mean(K.square(log_1-log_2),axis=-1)-Lambda*K.square(K.mean(log_1-log_2,axis=-1))

def pred_single_image_depth_using_fine(path):
    model=load_model(fine_dir,custom_objects={'scale_invarient_error':scale_invarient_error})
    img_array=cv2.imread(path)
    img_array=np.expand_dims(img_array,axis=0)
    img_array=np.array([cv2.resize(img_array[i],(480,640)) for i in range(1)])
    img_array=np.array([cv2.pyrDown(img_array[i]) for i in range(1)])
    img_array=rescale(img_array)
    out=model.predict(img_array)
    return out

def pred_single_image_depth_using_coarse(path):
    model=load_model(coarse_dir,custom_objects={'scale_invarient_error':scale_invarient_error})
    img_array=cv2.imread(path)
    img_array=np.expand_dims(img_array,axis=0)
    img_array=np.array([cv2.resize(img_array[i],(480,640)) for i in range(1)])
    img_array=np.array([cv2.pyrDown(img_array[i]) for i in range(1)])
    img_array=rescale(img_array)
    out=model.predict(img_array)
    return out

def pred_single_image_depth_using_coarse_array(image_array):
    model=load_model(coarse_dir,custom_objects={'scale_invarient_error':scale_invarient_error})
    image_array=np.expand_dims(image_array,axis=0)
    image_array=np.array([cv2.resize(image_array[i],(480,640)) for i in range(1)])
    image_array=np.array([cv2.pyrDown(image_array[i]) for i in range(1)])
    image_array=rescale(image_array)
    out=model.predict(image_array)
    return out

def pred_single_image_depth_using_fine_array(image_array):
    model=load_model(fine_dir,custom_objects={'scale_invarient_error':scale_invarient_error})
    image_array=np.expand_dims(image_array,axis=0)
    image_array=np.array([cv2.resize(image_array[i],(480,640)) for i in range(1)])
    image_array=np.array([cv2.pyrDown(image_array[i]) for i in range(1)])
    image_array=rescale(image_array)
    out=model.predict(image_array)
    return out
def display_image(path):
    img_array=plt.imread(path)
    img_array=np.expand_dims(img_array,axis=0) 
    img_array=np.array([cv2.resize(img_array[i],(480,640)) for i in range(1)])
    img_array=rescale(img_array)
    plt.imshow(img_array[0])
    
def eval(eval_dir):
    #load_model
    model=load_model(eval_dir,custom_objects={'scale_invarient_error':scale_invarient_error})
    print(model.evaluate(X_test,y_test))  
    
def rescale(data):
    data=data.astype('float32')
    data/=255
    
    return data

# %% [markdown]
# # Data script

# %%
def convert(path):
    with open(path+'INDEX.txt','r') as cafe:
        data_list=cafe.readlines()
    data_list=[x.strip('\n') for x in data_list]
    data=[]
    flag=0
    for i in data_list:
        if i[0]=='d':
            flag=1
            str2=i
        if i[0]=='r':
            if flag==1:
                flag=2
                str1=i
                data.append([str1,str2])
    X=[]
    y=[]
    for i in data:
        img1=cv2.imread(path+i[0])
        img2=cv2.imread(path+i[1],0)
        X.append(img1)
        y.append(img2)
    return np.array(X),np.array(y)

# %% [markdown]
# # Feature engineering

# %%
X_1,y_1=convert(path1)
X_2,y_2=convert(path2)
X_3,y_3=convert(path3)
print(X_1.shape,y_1.shape)
print(X_2.shape,y_2.shape)
print(X_3.shape,y_3.shape)
X_4=np.concatenate((X_1,X_2),axis=0)
y_4=np.concatenate((y_1,y_2),axis=0)
X_data=np.concatenate((X_4,X_3),axis=0)
y_data=np.concatenate((y_4,y_3),axis=0)
print(X_data.shape,y_data.shape)
# Out:
# (623, 480, 640, 3) (623, 480, 640)
# (480, 480, 640, 3) (480, 480, 640)
# (734, 480, 640, 3) (734, 480, 640)
# (1837, 480, 640, 3) (1837, 480, 640)

# %%
X_data=rescale(X_data)
y_data=rescale(y_data)

# %% [markdown]
# # Resize

# %%
X_data=np.array([cv2.resize(X_data[i],(480,640)) for i in range(1837)])
y_data=np.array([cv2.resize(y_data[i],(480,640)) for i in range(1837)])

# %% [markdown]
# # Training/testing data

# %%
X_train=X_data[:1200]
y_train=y_data[:1200]

# %%
X_test=X_data[1200:1837]
y_test=y_data[1200:1837]

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1200, 640, 480, 3)
# (1200, 640, 480)
# (637, 640, 480, 3)
# (637, 640, 480)

# %%
X_train=np.array([cv2.pyrDown(X_train[i]) for i in range(1200)])
y_train=np.array([cv2.pyrDown(y_train[i]) for i in range(1200)])
X_test=np.array([cv2.pyrDown(X_test[i]) for i in range(637)])
y_test=np.array([cv2.pyrDown(y_test[i]) for i in range(637)])

# %%
y_train=np.array([cv2.pyrDown(y_train[i]) for i in range(1200)])
y_test=np.array([cv2.pyrDown(y_test[i]) for i in range(637)])

# %%
y_train=np.array([cv2.pyrDown(y_train[i]) for i in range(1200)])
y_test=np.array([cv2.pyrDown(y_test[i]) for i in range(637)])

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1200, 320, 240, 3)
# (1200, 80, 60)
# (637, 320, 240, 3)
# (637, 80, 60)

# %% [markdown]
# # Configurations

# %%
batch_size=32
epochs=30
img_row=640
img_cols=480
learning_rate=0.1
momentum=0.9
Lambda=0.5

# %% [markdown]
# # Deep Network

# %% [markdown]
# ## coarse network

# %%
def train_coarse():
    inputs=Input(shape=(int(img_row/2),int(img_cols/2),3))

    #coarse_1
    coarse_1=Convolution2D(96,(11,11),strides=(4,4),padding='same')(inputs)
    coarse_1=Activation('relu')(coarse_1)
    coarse_1=MaxPooling2D(pool_size=(2, 2))(coarse_1)

    #coarse_2
    coarse_2=Convolution2D(256,(5,5),padding='same')(coarse_1)
    coarse_2=Activation('relu')(coarse_2)
    coarse_2=MaxPooling2D(pool_size=(2,2))(coarse_2)

    #coarse_3
    coarse_3=Convolution2D(384,(3,3),padding='same')(coarse_2)
    coarse_3=Activation('relu')(coarse_3)

    #coarse_4
    coarse_4=Convolution2D(384,(3,3),padding='same')(coarse_3)
    coarse_4=Activation('relu')(coarse_4)

    #coarse_5
    coarse_5=Convolution2D(256,(3,3),padding='same',)(coarse_4)
    coarse_5=Activation('relu')(coarse_5)
    coarse_5=MaxPooling2D(pool_size=(2,2))(coarse_5)

    #coarse_6
    coarse_6=Flatten(name='coarse_6')(coarse_5)
    coarse_6=Dense(4096)(coarse_6)
    coarse_6=Activation('relu')(coarse_6)
    coarse_6=Dropout(0.5)(coarse_6)

    # Coarse 7
    coarse_7=Dense((int(img_row/8))*(int(img_cols/8)))(coarse_6)
    coarse_7=Activation('linear')(coarse_7)
    coarse_7=Reshape((int(img_row/8),int(img_cols/8)))(coarse_7)
        
    model=Model(input=inputs,output=coarse_7)
    model.compile(loss=scale_invarient_error,optimizer=SGD(learning_rate,momentum),metrics=['accuracy'])
    model.summary()                    
        
                               
    model.fit(X_train,y_train,epochs=epochs,batch_size=batch_size,validation_split=0.2)
                               
    #save_model
    model.save(coarse_dir)

# %% [markdown]
# # Run_coarse

# %%
# %time
train_coarse()
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 79.2 µs
# /home/cse/ug/16075030/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:38: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("re...)`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 320, 240, 3)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 80, 60, 96)        34944
# _________________________________________________________________
# activation_7 (Activation)    (None, 80, 60, 96)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 40, 30, 96)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 40, 30, 256)       614656
# _________________________________________________________________
# activation_8 (Activation)    (None, 40, 30, 256)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 20, 15, 256)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 20, 15, 384)       885120
# _________________________________________________________________
# activation_9 (Activation)    (None, 20, 15, 384)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 20, 15, 384)       1327488
# _________________________________________________________________
# activation_10 (Activation)   (None, 20, 15, 384)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 20, 15, 256)       884992
# _________________________________________________________________
# activation_11 (Activation)   (None, 20, 15, 256)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 10, 7, 256)        0
# _________________________________________________________________
# coarse_6 (Flatten)           (None, 17920)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              73404416
# _________________________________________________________________
# activation_12 (Activation)   (None, 4096)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4800)              19665600
# _________________________________________________________________
# activation_13 (Activation)   (None, 4800)              0
# _________________________________________________________________
# reshape_5 (Reshape)          (None, 80, 60)            0
# =================================================================
# Total params: 96,817,216
# Trainable params: 96,817,216
# Non-trainable params: 0
# _________________________________________________________________
# Train on 960 samples, validate on 240 samples
# Epoch 1/100
# 960/960 [==============================] - 187s 195ms/step - loss: 0.1302 - acc: 0.0192 - val_loss: 0.1013 - val_acc: 0.0327
# Epoch 2/100
# 960/960 [==============================] - 197s 205ms/step - loss: 0.0953 - acc: 0.0219 - val_loss: 0.0769 - val_acc: 0.0356
# Epoch 3/100
# 960/960 [==============================] - 175s 182ms/step - loss: 0.0741 - acc: 0.0220 - val_loss: 0.0602 - val_acc: 0.0345
# Epoch 4/100
# 960/960 [==============================] - 170s 177ms/step - loss: 0.0620 - acc: 0.0244 - val_loss: 0.0499 - val_acc: 0.0347
# Epoch 5/100
# 960/960 [==============================] - 193s 202ms/step - loss: 0.0548 - acc: 0.0237 - val_loss: 0.0433 - val_acc: 0.0332
# Epoch 6/100
# 960/960 [==============================] - 322s 336ms/step - loss: 0.0499 - acc: 0.0253 - val_loss: 0.0378 - val_acc: 0.0355
# Epoch 89/100
# 960/960 [==============================] - 165s 172ms/step - loss: 0.0125 - acc: 0.0458 - val_loss: 0.0208 - val_acc: 0.0404
# Epoch 90/100
# 960/960 [==============================] - 160s 167ms/step - loss: 0.0125 - acc: 0.0442 - val_loss: 0.0207 - val_acc: 0.0425
# Epoch 91/100
# 960/960 [==============================] - 158s 165ms/step - loss: 0.0124 - acc: 0.0446 - val_loss: 0.0208 - val_acc: 0.0387
# Epoch 92/100
# 960/960 [==============================] - 163s 170ms/step - loss: 0.0123 - acc: 0.0468 - val_loss: 0.0206 - val_acc: 0.0406
# Epoch 93/100
# 960/960 [==============================] - 159s 166ms/step - loss: 0.0123 - acc: 0.0462 - val_loss: 0.0208 - val_acc: 0.0399
# Epoch 94/100
# 960/960 [==============================] - 159s 165ms/step - loss: 0.0122 - acc: 0.0460 - val_loss: 0.0205 - val_acc: 0.0394
# Epoch 95/100
# 960/960 [==============================] - 159s 166ms/step - loss: 0.0121 - acc: 0.0461 - val_loss: 0.0210 - val_acc: 0.0401
# Epoch 96/100
# 960/960 [==============================] - 159s 165ms/step - loss: 0.0120 - acc: 0.0451 - val_loss: 0.0205 - val_acc: 0.0385
# Epoch 97/100
# 960/960 [==============================] - 159s 166ms/step - loss: 0.0120 - acc: 0.0470 - val_loss: 0.0206 - val_acc: 0.0418
# Epoch 98/100
# 960/960 [==============================] - 161s 168ms/step - loss: 0.0120 - acc: 0.0464 - val_loss: 0.0207 - val_acc: 0.0393
# Epoch 99/100
# 960/960 [==============================] - 169s 176ms/step - loss: 0.0119 - acc: 0.0462 - val_loss: 0.0206 - val_acc: 0.0385
# Epoch 100/100
# 960/960 [==============================] - 165s 172ms/step - loss: 0.0118 - acc: 0.0471 - val_loss: 0.0206 - val_acc: 0.0410

# %% [markdown]
# # Fine_layers

# %%
def train_fine():
    #load_coarse_model:
    model=load_model(coarse_dir,custom_objects={'scale_invarient_error':scale_invarient_error})
    
    for layers in model.layers:
        layers.trainable=False
    
    #fine_model
    inputs=model.input
    
    #fine_1:
    fine_1=Convolution2D(63,(9,9),strides=(2,2),padding='same')(inputs)
    fine_1=Activation('relu')(fine_1)
    fine_1=MaxPooling2D(pool_size=(2,2))(fine_1)
    
    #fine_2:
    coarse_output=model.output
    coarse_output=Reshape((int(img_row/8),int(img_cols/8),1))(coarse_output)
    fine_2=concatenate([fine_1,coarse_output],axis=3)
    
    #fine_3:
    fine_3=Convolution2D(64,(5,5),padding='same')(fine_2)
    fine_3=Activation('relu')(fine_3)
    
    #fine_4:
    fine_4=Convolution2D(1,(5,5),padding='same')(fine_3)
    fine_4=Activation('linear')(fine_4)
    fine_4=Reshape((int(img_row/8),int(img_cols/8)))(fine_4)
    
    model=Model(input=inputs,output=fine_4)
    model.compile(loss=scale_invarient_error,optimizer=SGD(learning_rate,momentum),metrics=['accuracy'])
    model.summary()
    
    
    model.fit(X_train,y_train,batch_size=batch_size,epochs=epochs,validation_split=0.2)
    
    #save model
    model.save(fine_dir)

# %% [markdown]
# # run fine_network

# %%
# %time
train_fine()
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 350 µs
# /home/cse/ug/16075030/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:30: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("re...)`
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 320, 240, 3)  0
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 80, 60, 96)   34944       input_1[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 80, 60, 96)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 40, 30, 96)   0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 40, 30, 256)  614656      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 40, 30, 256)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 20, 15, 256)  0           activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 20, 15, 384)  885120      max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 20, 15, 384)  0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 20, 15, 384)  1327488     activation_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 20, 15, 384)  0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 20, 15, 256)  884992      activation_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 20, 15, 256)  0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 10, 7, 256)   0           activation_11[0][0]
# __________________________________________________________________________________________________
# coarse_6 (Flatten)              (None, 17920)        0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 4096)         73404416    coarse_6[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 4096)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 4096)         0           activation_12[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 4800)         19665600    dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 160, 120, 63) 15372       input_1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 4800)         0           dense_2[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 160, 120, 63) 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 80, 60)       0           activation_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 80, 60, 63)   0           activation_17[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 80, 60, 1)    0           reshape_5[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 80, 60, 64)   0           max_pooling2d_7[0][0]
#                                                                  reshape_8[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 80, 60, 64)   102464      concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 80, 60, 64)   0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 80, 60, 1)    1601        activation_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 80, 60, 1)    0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 80, 60)       0           activation_19[0][0]
# ==================================================================================================
# Total params: 96,936,653
# Trainable params: 119,437
# Non-trainable params: 96,817,216
# __________________________________________________________________________________________________
# Train on 960 samples, validate on 240 samples
# Epoch 1/30
# 960/960 [==============================] - 276s 287ms/step - loss: 0.0552 - acc: 0.0344 - val_loss: 0.0246 - val_acc: 0.0349
# Epoch 2/30
# 960/960 [==============================] - 194s 202ms/step - loss: 0.0231 - acc: 0.0384 - val_loss: 0.0241 - val_acc: 0.0305
# Epoch 3/30
# 960/960 [==============================] - 196s 204ms/step - loss: 0.0085 - acc: 0.0458 - val_loss: 0.0208 - val_acc: 0.0285
# Epoch 4/30
# 960/960 [==============================] - 197s 205ms/step - loss: 0.0072 - acc: 0.0501 - val_loss: 0.0200 - val_acc: 0.0355
# Epoch 5/30
# 960/960 [==============================] - 201s 210ms/step - loss: 0.0069 - acc: 0.0574 - val_loss: 0.0204 - val_acc: 0.0426
# Epoch 6/30
# 960/960 [==============================] - 205s 213ms/step - loss: 0.0069 - acc: 0.0631 - val_loss: 0.0199 - val_acc: 0.0500
# Epoch 7/30
# 960/960 [==============================] - 207s 216ms/step - loss: 0.0068 - acc: 0.0661 - val_loss: 0.0197 - val_acc: 0.0356
# Epoch 8/30
# 960/960 [==============================] - 211s 220ms/step - loss: 0.0067 - acc: 0.0659 - val_loss: 0.0209 - val_acc: 0.0312
# Epoch 9/30
# 960/960 [==============================] - 270s 281ms/step - loss: 0.0068 - acc: 0.0713 - val_loss: 0.0197 - val_acc: 0.0391
# Epoch 10/30
# 960/960 [==============================] - 332s 346ms/step - loss: 0.0067 - acc: 0.0735 - val_loss: 0.0202 - val_acc: 0.0395
# Epoch 11/30
# 960/960 [==============================] - 322s 336ms/step - loss: 0.0067 - acc: 0.0750 - val_loss: 0.0204 - val_acc: 0.0404
# Epoch 12/30
# 960/960 [==============================] - 317s 330ms/step - loss: 0.0067 - acc: 0.0764 - val_loss: 0.0197 - val_acc: 0.0469
# Epoch 13/30
# 960/960 [==============================] - 299s 312ms/step - loss: 0.0068 - acc: 0.0829 - val_loss: 0.0195 - val_acc: 0.0592
# Epoch 14/30
# 960/960 [==============================] - 314s 327ms/step - loss: 0.0066 - acc: 0.0829 - val_loss: 0.0204 - val_acc: 0.0374
# Epoch 15/30
# 960/960 [==============================] - 319s 333ms/step - loss: 0.0065 - acc: 0.0813 - val_loss: 0.0201 - val_acc: 0.0344
# Epoch 16/30
# 960/960 [==============================] - 299s 312ms/step - loss: 0.0065 - acc: 0.0846 - val_loss: 0.0195 - val_acc: 0.0439
# Epoch 17/30
# 960/960 [==============================] - 303s 316ms/step - loss: 0.0066 - acc: 0.0883 - val_loss: 0.0197 - val_acc: 0.0559
# Epoch 18/30
# 960/960 [==============================] - 310s 323ms/step - loss: 0.0065 - acc: 0.0899 - val_loss: 0.0196 - val_acc: 0.0571
# Epoch 19/30
# 960/960 [==============================] - 352s 367ms/step - loss: 0.0065 - acc: 0.0941 - val_loss: 0.0207 - val_acc: 0.0351
# Epoch 20/30
# 960/960 [==============================] - 291s 303ms/step - loss: 0.0065 - acc: 0.0942 - val_loss: 0.0197 - val_acc: 0.0405
# Epoch 21/30
# 960/960 [==============================] - 305s 318ms/step - loss: 0.0065 - acc: 0.0939 - val_loss: 0.0196 - val_acc: 0.0400
# Epoch 22/30
# 960/960 [==============================] - 322s 335ms/step - loss: 0.0065 - acc: 0.0931 - val_loss: 0.0197 - val_acc: 0.0396
# Epoch 23/30
# 960/960 [==============================] - 322s 336ms/step - loss: 0.0064 - acc: 0.0948 - val_loss: 0.0193 - val_acc: 0.0432
# Epoch 24/30
# 960/960 [==============================] - 322s 335ms/step - loss: 0.0064 - acc: 0.0975 - val_loss: 0.0194 - val_acc: 0.0438
# Epoch 25/30
# 960/960 [==============================] - 367s 383ms/step - loss: 0.0065 - acc: 0.0976 - val_loss: 0.0201 - val_acc: 0.0393
# Epoch 26/30
# 960/960 [==============================] - 361s 376ms/step - loss: 0.0064 - acc: 0.0997 - val_loss: 0.0200 - val_acc: 0.0385
# Epoch 27/30
# 960/960 [==============================] - 298s 311ms/step - loss: 0.0064 - acc: 0.0954 - val_loss: 0.0199 - val_acc: 0.0404
# Epoch 28/30
# 960/960 [==============================] - 332s 345ms/step - loss: 0.0063 - acc: 0.1009 - val_loss: 0.0198 - val_acc: 0.0371
# Epoch 29/30
# 960/960 [==============================] - 356s 371ms/step - loss: 0.0063 - acc: 0.1010 - val_loss: 0.0195 - val_acc: 0.0393
# Epoch 30/30
# 960/960 [==============================] - 367s 382ms/step - loss: 0.0063 - acc: 0.1041 - val_loss: 0.0199 - val_acc: 0.0374

# %% [markdown]
# # Evaluation

# %%
eval(coarse_dir)
# Out:
# 637/637 [==============================] - 24s 38ms/step
# [0.036320632525384894, 0.034497645193801572]

# %%
eval(fine_dir)
# Out:
# 637/637 [==============================] - 48s 75ms/step
# [0.035025646170276675, 0.075235477749556537]

# %% [markdown]
# # Examples

# %%
display_image('test_data/'+'r-1295527097.254250-1959004445.ppm')

# %%
ans=pred_single_image_depth_using_fine('test_data/'+'r-1295527097.254250-1959004445.ppm')
plt.imshow(ans[0])

# %%
plt.imshow(X_1[0])

# %%
plt.imshow(y_1[0])

# %%
ans=pred_single_image_depth_using_fine_array(X_1[0])
plt.imshow(ans[0])
